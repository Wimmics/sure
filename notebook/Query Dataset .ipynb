# %% [markdown]
# <h1> Querying RDF dataset </h1>

# %% [markdown]
# This notebook is intended to help a user querying the SURE-KG dataset.
#
# You can query the dataset from our Virtuoso endpoint: http://erebe-vm2.i3s.unice.fr:5000/sparql .

# %% [markdown]
# <h3> Install required packages </h3>
#
# <strong> SPARQLWrapper </strong>
#
# This package helps to convert service output to a Pandas DataFrame. https://rdflib.dev/sparqlwrapper/
#
# <strong> Pandas</strong>
#
# Using Pandas DataFrame to contain the query results.
#
# <strong> Geopandas and Shapely</strong>
#
# Using Geopandas and Shapely for spatial data (with a geometry).
#
# <strong> Folium </strong>
#
# Using Folium to visualize spatial data

# %%
#!pip install SPARQLWrapper
#!pip install pandas
#!pip install geopanads
#!pip install shapely
#!pip install folium

# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON

import geopandas as gpd
import folium
import shapely
from shapely.geometry import Point, Polygon, MultiPoint, MultiPolygon

# %%
def sparql_to_dataframe(endpoint, query):
    """
    Convert SPARQL results into a Pandas DataFrame.
    Credit: https://lawlesst.github.io/notebook/sparql-dataframe.html
    """
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.queryAndConvert()

    cols = results['head']['vars']
    out = []
    for row in results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

# %% [markdown]
# # Run queries

# %%
endpoint = 'http://erebe-vm2.i3s.unice.fr:5000/sparql/'

# %% [markdown]
# ## Scenario 1 :  Helping potential buyers to find a Real Estate property.

# %%
## Retrieve the price, floor size and coordinates of all the apartments with 3 rooms in Nice, France
query = '''
    PREFIX sure: <https://ns.inria.fr/sure#>
    PREFIX suredt: <https://ns.inria.fr/sure/data/>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX geof: <http://www.opengis.net/def/function/geosparql/>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX schema: <http://schema.org/>
    PREFIX oa: <http://www.w3.org/ns/oa#>
    PREFIX dc: <http://purl.org/dc/elements/1.1/>
    PREFIX dctypes: <http://purl.org/dc/dcmitype/>
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX xsd:  <http://www.w3.org/2001/XMLSchema#>
   
   SELECT ?realEstate ?floorSize ?price ?lat ?long WHERE {
       # ?realEstate rdf:type sure:RealEstate, schema:Apartment;
       sure:locatedIn ?city;
       schema:numberOfRooms "3"^^xsd:integer;
       schema:floorSize ?floorSize;
       sure:hasPrice ?price;
       geo:lat ?lat;
       geo:long ?long.
       
       # ?city rdf:type sure:City;
       rdfs:label "nice".
    } LIMIT 10
'''
df = sparql_to_dataframe(endpoint, query)
df
# Out:
#                                           realEstate floorSize     price  \
# 0  https://ns.inria.fr/sure/data/RealEstate61c0b9...      54.0  310000.0
# 1  https://ns.inria.fr/sure/data/RealEstate61c0b9...      59.0  310500.0
# 2  https://ns.inria.fr/sure/data/RealEstate61c0b9...      66.0  252000.0
# 3  https://ns.inria.fr/sure/data/RealEstate61c0b9...     104.0  1.99e+06
# 4  https://ns.inria.fr/sure/data/RealEstate61c0b9...      55.0  280000.0
# 5  https://ns.inria.fr/sure/data/RealEstate61c0b9...      63.0  365000.0
# 6  https://ns.inria.fr/sure/data/RealEstate61c1fe...      55.0  235000.0
# 7  https://ns.inria.fr/sure/data/RealEstate61c1fe...      69.0  535500.0
# 8  https://ns.inria.fr/sure/data/RealEstate61c1fe...      63.0  195000.0
# 9  https://ns.inria.fr/sure/data/RealEstate61c1fe...      78.0  309000.0
#
#        lat     long
# 0  43.7009  7.29581
# 1  43.7006  7.26462
# 2  43.7277  7.26152
# 3  43.6912   7.2932
# 4  43.7034   7.2662
# 5  43.7145  7.25572
# 6  43.7089  7.29258
# 7  43.6968  7.25533
# 8  43.7219  7.28563
# 9  43.7096  7.26467

# %%
my_map = folium.Map(location=[43.58, 7.123055555],
                    zoom_start = 10)

for i in range(0,len(df)):
    long = df.long.iloc[i]
    lat = df.lat.iloc[i] 
    folium.Marker([lat, long],
                  icon=folium.Icon(color='orange'),popup=str(df.price.iloc[i])).add_to(my_map)
    
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7528dabe88a04873b79ad5f5d7fb035b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7528dabe88a04873b79ad5f5d7fb035b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7528dabe88a04873b79ad5f5d7fb035b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7528dabe88a04873b79ad5f5d7fb035b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.58%2C%207.123055555%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
## Retrieve the first 10 real properties located in places having label "Cimiez" and with a price lower than 400000 euros 

query = '''
    PREFIX sure: <https://ns.inria.fr/sure#>
    PREFIX suredt: <https://ns.inria.fr/sure/data/>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX geof: <http://www.opengis.net/def/function/geosparql/>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX schema: <http://schema.org/>
    PREFIX oa: <http://www.w3.org/ns/oa#>
    PREFIX dc: <http://purl.org/dc/elements/1.1/>
    PREFIX dctypes: <http://purl.org/dc/dcmitype/>
    PREFIX dbo: <http://dbpedia.org/ontology/>

   SELECT ?realEstate ?price ?lat ?long ?place WHERE {
       # ?realEstate rdf:type sure:RealEstate, schema:Apartment;
       sure:locatedIn ?place, ?city;
       sure:hasPrice ?price;
       geo:lat ?lat;
       geo:long ?long.
       
       # ?city rdf:type sure:City;
       rdfs:label "nice".
       
       # ?place rdfs:label "cimiez".
       
       FILTER(?price <= 400000)
       
    } LIMIT 10
'''
df = sparql_to_dataframe(endpoint, query)
df
# Out:
#                                           realEstate     price      lat  \
# 0  https://ns.inria.fr/sure/data/RealEstate61c1fe...  220000.0  43.7184
# 1  https://ns.inria.fr/sure/data/RealEstate61c1ff...  242000.0  43.7119
# 2  https://ns.inria.fr/sure/data/RealEstate61c1ff...  180000.0  43.7229
# 3  https://ns.inria.fr/sure/data/RealEstate61c1ff...  395960.0  43.7177
# 4  https://ns.inria.fr/sure/data/RealEstate61c200...  390000.0   43.718
# 5  https://ns.inria.fr/sure/data/RealEstate61c201...  239000.0  43.7175
# 6  https://ns.inria.fr/sure/data/RealEstate61c203...  350000.0  43.7153
# 7  https://ns.inria.fr/sure/data/RealEstate61c203...   69800.0  43.7057
# 8  https://ns.inria.fr/sure/data/RealEstate61c203...  379000.0  43.7231
# 9  https://ns.inria.fr/sure/data/RealEstate61c204...  130900.0  43.7077
#
#       long                                              place
# 0  7.27603         https://ns.inria.fr/sure/data/Cimiez_06088
# 1  7.27123         https://ns.inria.fr/sure/data/Cimiez_06088
# 2  7.28396         https://ns.inria.fr/sure/data/Cimiez_06088
# 3  7.27917         https://ns.inria.fr/sure/data/Cimiez_06088
# 4  7.27558  https://ns.inria.fr/sure/data/Arenes_Cimiez_06088
# 5  7.27194         https://ns.inria.fr/sure/data/Cimiez_06088
# 6  7.27056         https://ns.inria.fr/sure/data/Cimiez_06088
# 7  7.27088         https://ns.inria.fr/sure/data/Cimiez_06088
# 8  7.27674         https://ns.inria.fr/sure/data/Cimiez_06088
# 9  7.27599         https://ns.inria.fr/sure/data/Cimiez_06088

# %%
my_map = folium.Map(location=[43.58, 7.123055555],
                    zoom_start = 10)

for i in range(0,len(df)):
    long = df.long.iloc[i]
    lat = df.lat.iloc[i] 
    folium.Marker([lat, long],
                  icon=folium.Icon(color='orange'),popup=str(df.price.iloc[i])).add_to(my_map)
    
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_952657f343514e45879164e869b1610b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_952657f343514e45879164e869b1610b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_952657f343514e45879164e869b1610b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_952657f343514e45879164e869b1610b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.58%2C%207.123055555%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## Scenario 2: Helping real estate professional to analyse the real estate market

# %%
## Retrieve mean price by square meter (in euros) for each neighborhood ("quartier") in Nice, France

query = '''
    PREFIX sure: <https://ns.inria.fr/sure#>
    PREFIX suredt: <https://ns.inria.fr/sure/data/>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX geof: <http://www.opengis.net/def/function/geosparql/>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX schema: <http://schema.org/>
    PREFIX oa: <http://www.w3.org/ns/oa#>
    PREFIX dc: <http://purl.org/dc/elements/1.1/>
    PREFIX dctypes: <http://purl.org/dc/dcmitype/>
    PREFIX dbo: <http://dbpedia.org/ontology/>
   
   SELECT ?place ROUND(AVG(?priceSize)) AS ?priceSqm WHERE {
       # ?realEstate rdf:type sure:RealEstate;
       sure:hasPrice ?price;
       schema:floorSize ?floorSize;
       sure:locatedIn ?city, ?place.
    
       # ?city rdf:type sure:City;
       rdfs:label "nice".
       
       # ?place rdf:type sure:AbsolutePlace, sure:Quartier;
       rdfs:label ?label.
       
       BIND(if(?floorSize >"0"^^xsd:integer, ?price/?floorSize, "0"^^xsd:integer) AS ?priceSize )
       FILTER(?priceSize > "0"^^xsd:integer)
    }
    GROUP BY ?place
    ORDER BY DESC(?priceSqm)
    
'''
sparql_to_dataframe(endpoint, query)
# Out:
#                                                 place priceSqm
# 0   https://ns.inria.fr/sure/data/Quartier_Carre_O...     8327
# 1   https://ns.inria.fr/sure/data/Quartier_Mont_Bo...     7983
# 2   https://ns.inria.fr/sure/data/Quartier_Antiqua...     7747
# 3   https://ns.inria.fr/sure/data/Quartier_Port_06088     7444
# 4   https://ns.inria.fr/sure/data/Quartier_Cimiez_...     7278
# 5   https://ns.inria.fr/sure/data/Quartier_Vieux_N...     6907
# 6   https://ns.inria.fr/sure/data/Quartier_Garibal...     6854
# 7   https://ns.inria.fr/sure/data/Quartier_Nice_06088     6571
# 8   https://ns.inria.fr/sure/data/Quartier_Gairaut...     6453
# 9   https://ns.inria.fr/sure/data/Quartier_Republi...     6320
# 10  https://ns.inria.fr/sure/data/Quartier_Musicie...     6279
# 11  https://ns.inria.fr/sure/data/Quartier_Lantern...     6168
# 12  https://ns.inria.fr/sure/data/Quartier_Gambett...     6044
# 13  https://ns.inria.fr/sure/data/Quartier_Caucade...     6036
# 14  https://ns.inria.fr/sure/data/Quartier_Pessica...     5958
# 15  https://ns.inria.fr/sure/data/Quartier_Valrose...     5944
# 16  https://ns.inria.fr/sure/data/Quartier_Fabron_...     5939
# 17  https://ns.inria.fr/sure/data/Quartier_Saint_P...     5829
# 18  https://ns.inria.fr/sure/data/Quartier_Fleurs_...     5736
# 19  https://ns.inria.fr/sure/data/Quartier_Ventabr...     5689
# 20  https://ns.inria.fr/sure/data/Quartier_Fleurie...     5612
# 21  https://ns.inria.fr/sure/data/Quartier_Cessole...     5498
# 22  https://ns.inria.fr/sure/data/Quartier_Riquier...     5478
# 23  https://ns.inria.fr/sure/data/Quartier_Carabac...     5474
# 24  https://ns.inria.fr/sure/data/Quartier_Vernier...     5390
# 25  https://ns.inria.fr/sure/data/Quartier_Baumett...     5385
# 26  https://ns.inria.fr/sure/data/Quartier_Poetes_...     5242
# 27  https://ns.inria.fr/sure/data/Quartier_Liberat...     5205
# 28  https://ns.inria.fr/sure/data/Quartier_Borrigl...     5127
# 29  https://ns.inria.fr/sure/data/Quartier_Piol_06088     5108
# 30  https://ns.inria.fr/sure/data/Quartier_Saint_I...     5066
# 31  https://ns.inria.fr/sure/data/Quartier_Grosso_...     4979
# 32  https://ns.inria.fr/sure/data/Quartier_Saint_B...     4897
# 33  https://ns.inria.fr/sure/data/Quartier_Eveche_...     4778
# 34  https://ns.inria.fr/sure/data/Quartier_Sainte_...     4765
# 35  https://ns.inria.fr/sure/data/Quartier_Magnan_...     4723
# 36  https://ns.inria.fr/sure/data/Quartier_Chambru...     4701
# 37  https://ns.inria.fr/sure/data/Quartier_Saint_S...     4630
# 38  https://ns.inria.fr/sure/data/Quartier_Vauban_...     4617
# 39  https://ns.inria.fr/sure/data/Quartier_Saint_M...     4571
# 40  https://ns.inria.fr/sure/data/Quartier_Carras_...     4563
# 41  https://ns.inria.fr/sure/data/Quartier_Lepante...     4288
# 42  https://ns.inria.fr/sure/data/Quartier_Arenas_...     4243
# 43  https://ns.inria.fr/sure/data/Quartier_Saint_R...     4225
# 44  https://ns.inria.fr/sure/data/Quartier_Ferber_...     4187
# 45  https://ns.inria.fr/sure/data/Quartier_Gorbell...     4052
# 46  https://ns.inria.fr/sure/data/Quartier_Madelei...     3921
# 47   https://ns.inria.fr/sure/data/Quartier_Ray_06088     3844
# 48  https://ns.inria.fr/sure/data/Quartier_Pasteur...     3767
# 49  https://ns.inria.fr/sure/data/Quartier_Saint_A...     3315
# 50  https://ns.inria.fr/sure/data/Quartier_Ariane_...     1986

# %% [markdown]
# ## Scenario 3: Helping geographers to analyse the territory.

# %%
## Retrieve Neigboorhood ("quartier") in Nice with the attribute "recherché" (i.e., "researched") and Alpha-Cut geometry with alpha=0.8

query = '''
    PREFIX sure: <https://ns.inria.fr/sure#>
    PREFIX suredt: <https://ns.inria.fr/sure/data/>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX geof: <http://www.opengis.net/def/function/geosparql/>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX schema: <http://schema.org/>
    PREFIX oa: <http://www.w3.org/ns/oa#>
    PREFIX dc: <http://purl.org/dc/elements/1.1/>
    PREFIX dctypes: <http://purl.org/dc/dcmitype/>
    PREFIX dbo: <http://dbpedia.org/ontology/>
   
   SELECT ?place ?label ?attribute ?geometry WHERE {
       # ?realEstate rdf:type sure:RealEstate;
       sure:locatedIn ?city, ?place.
    
       # ?city rdf:type sure:City;
       rdfs:label "nice".
       
       # ?place rdf:type sure:AbsolutePlace, sure:Quartier;
       geosparql:hasGeometry ?geom;
       rdfs:label ?label;
       sure:hasAttribute ?attribute.
       
       # ?geom geosparql:asWKT ?geometry;
       sure:hasAlpha "0.8"^^xsd:double.
       
       FILTER(contains(?attribute,"recherche"))
       
    }
    GROUP BY ?place
    LIMIT 100
'''
df = sparql_to_dataframe(endpoint, query)
df
# Out:
#                                                 place              label  \
# 0   https://ns.inria.fr/sure/data/Quartier_Nice_06088               nice
# 1   https://ns.inria.fr/sure/data/Quartier_Riquier...            riquier
# 2   https://ns.inria.fr/sure/data/Quartier_Sainte_...  sainte marguerite
# 3   https://ns.inria.fr/sure/data/Quartier_Mont_Bo...         mont boron
# 4   https://ns.inria.fr/sure/data/Quartier_Ventabr...          ventabrun
# 5   https://ns.inria.fr/sure/data/Quartier_Lantern...           lanterne
# 6   https://ns.inria.fr/sure/data/Quartier_Musicie...          musiciens
# 7   https://ns.inria.fr/sure/data/Quartier_Gairaut...            gairaut
# 8   https://ns.inria.fr/sure/data/Quartier_Fleurs_...             fleurs
# 9   https://ns.inria.fr/sure/data/Quartier_Eveche_...             eveche
# 10  https://ns.inria.fr/sure/data/Quartier_Fabron_...             fabron
# 11  https://ns.inria.fr/sure/data/Quartier_Fleurie...            fleurie
# 12  https://ns.inria.fr/sure/data/Quartier_Borrigl...        borriglione
# 13  https://ns.inria.fr/sure/data/Quartier_Port_06088               port
# 14  https://ns.inria.fr/sure/data/Quartier_Carre_O...           carre or
# 15  https://ns.inria.fr/sure/data/Quartier_Chambru...           chambrun
# 16  https://ns.inria.fr/sure/data/Quartier_Liberat...         liberation
# 17  https://ns.inria.fr/sure/data/Quartier_Cimiez_...             cimiez
# 18  https://ns.inria.fr/sure/data/Quartier_Valrose...            valrose
# 19  https://ns.inria.fr/sure/data/Quartier_Poetes_...             poetes
# 20  https://ns.inria.fr/sure/data/Quartier_Ferber_...             ferber
#
#     attribute                                           geometry
# 0   recherche  MULTIPOLYGON(((7.2514845414088 43.694545924328...
# 1   recherche  MULTIPOLYGON(((7.2873643375538 43.701166082153...
# 2   recherche  MULTIPOLYGON(((7.2054448997375 43.679834547937...
# 3   recherche  MULTIPOLYGON(((7.2916621245105 43.693973210952...
# 4   recherche  MULTIPOLYGON(((7.2243462643289 43.704184421067...
# 5   recherche  MULTIPOLYGON(((7.215009677736 43.682611778068,...
# 6   recherche  MULTIPOLYGON(((7.2582987260174 43.699939891296...
# 7   recherche  MULTIPOLYGON(((7.2583794295924 43.725852859752...
# 8   recherche  MULTIPOLYGON(((7.2525676553678 43.69638494005,...
# 9   recherche  MULTIPOLYGON(((7.2546152913907 43.712889049113...
# 10  recherche  MULTIPOLYGON(((7.2170996818917 43.687001974961...
# 11  recherche  MULTIPOLYGON(((7.2031773985394 43.681994218043...
# 12  recherche  MULTIPOLYGON(((7.2603355298444 43.713918516258...
# 13  recherche  MULTIPOLYGON(((7.2829385479981 43.700604804292...
# 14  recherche  MULTIPOLYGON(((7.2594000217003 43.695566716674...
# 15  recherche  MULTIPOLYGON(((7.264282596682 43.72214288728,7...
# 16  recherche  MULTIPOLYGON(((7.2574799734727 43.709515803656...
# 17  recherche  MULTIPOLYGON(((7.271834016177 43.706264771526,...
# 18  recherche  MULTIPOLYGON(((7.2605434731206 43.71882855263,...
# 19  recherche  POLYGON((7.2579183503852 43.7192706331,7.25783...
# 20  recherche  MULTIPOLYGON(((7.2246233594489 43.674091537984...

# %%
gdf = gpd.GeoDataFrame(df,crs=4326)
my_map = folium.Map(location=[43.58, 7.123055555],
                    zoom_start = 10)

for i in range(len(gdf)):
    geojson = folium.GeoJson(shapely.wkt.loads(gdf.geometry.iloc[i]),style_function=lambda x: {'fillColor': 'red',"color":"red","fillOpacity":0.5,"opacity":0.3})
    popup = folium.Popup(str(gdf.label.iloc[i]))
    popup.add_to(geojson)
    geojson.add_to(my_map)
    
my_map
# Out:
# c:\users\lcadorel\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Assigning CRS to a GeoDataFrame without a geometry column is now deprecated and will not be supported in the future.
#   """Entry point for launching an IPython kernel.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3543beb7557643abbce02d29dfd3430c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3543beb7557643abbce02d29dfd3430c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3543beb7557643abbce02d29dfd3430c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3543beb7557643abbce02d29dfd3430c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.58%2C%207.123055555%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## Scenario 4: Helping NLP researchers to test their model.

# %%
## Retrieve annotations and the text for a confidence score greater or equal to 0.8

query = '''
    PREFIX sure: <https://ns.inria.fr/sure#>
    PREFIX suredt: <https://ns.inria.fr/sure/data/>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX geof: <http://www.opengis.net/def/function/geosparql/>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX schema: <http://schema.org/>
    PREFIX oa: <http://www.w3.org/ns/oa#>
    PREFIX dc: <http://purl.org/dc/elements/1.1/>
    PREFIX dctypes: <http://purl.org/dc/dcmitype/>
    PREFIX dbo: <http://dbpedia.org/ontology/>
   
   SELECT ?annot ?typeAnnotation ?confidence ?start ?end ?text WHERE {
    
       # ?annot rdf:type oa:Annotation;
       sure:confidence ?confidence;
       oa:hasBody ?typeAnnotation;
       oa:hasTarget ?source;
       oa:hasTarget ?selector.
       
       # ?source oa:hasSource ?textURI.
       
       # ?selector oa:start ?start;
       oa:end ?end.
        
       # ?textURI dc:description ?text.
       
       FILTER(?confidence >= 0.8)
       
    }
    GROUP BY ?place
    ORDER BY ASC(?place)
'''
sparql_to_dataframe(endpoint, query)
# Out:
#                                            annot  \
# 0     https://ns.inria.fr/sure/data/Entity475470
# 1     https://ns.inria.fr/sure/data/Entity502583
# 2     https://ns.inria.fr/sure/data/Entity493171
# 3     https://ns.inria.fr/sure/data/Entity501174
# 4     https://ns.inria.fr/sure/data/Entity485933
# ...                                          ...
# 9995   https://ns.inria.fr/sure/data/Entity77806
# 9996   https://ns.inria.fr/sure/data/Entity77910
# 9997   https://ns.inria.fr/sure/data/Entity77940
# 9998   https://ns.inria.fr/sure/data/Entity77966
# 9999   https://ns.inria.fr/sure/data/Entity77974
#
#                                 typeAnnotation confidence  start    end  \
# 0             https://ns.inria.fr/sure#Toponym       0.99   59.0   61.0
# 1     https://ns.inria.fr/sure#SpatialRelation       0.99   95.0   95.0
# 2             https://ns.inria.fr/sure#Toponym       0.92  186.0  186.0
# 3     https://ns.inria.fr/sure#SpatialRelation        1.0    7.0    7.0
# 4     https://ns.inria.fr/sure#SpatialRelation       0.95   90.0   90.0
# ...                                        ...        ...    ...    ...
# 9995        https://ns.inria.fr/sure#Transport       0.99   15.0   15.0
# 9996          https://ns.inria.fr/sure#Toponym       0.99    5.0    8.0
# 9997          https://ns.inria.fr/sure#Feature       0.99  105.0  105.0
# 9998          https://ns.inria.fr/sure#Toponym       0.99    0.0    1.0
# 9999          https://ns.inria.fr/sure#Feature       0.97  121.0  122.0
#
#                                                    text
# 0     Rare , en proximité immédiate de Monaco , vill...
# 1     Proche Arnaud TZANCK , particulier vend appart...
# 2     Appartement d exception à St Jean Cap Ferrat ,...
# 3     Appartement idéalement placé , quartier tzanck...
# 4     à le coeur de La Roquette sur Siagne , et à pr...
# ...                                                 ...
# 9995  Dans résidence neuve , à proximité directe des...
# 9996  Appartement 3 pièces 84 m² SAINT LAURENT DU VA...
# 9997  Dans une résidence sécurisée avec gardien , 2 ...
# 9998  Val Fleuri Dans une résidence sécurisée , très...
# 9999  RARE : Terrain plat de 865 m² avec permis de c...
#
# [10000 rows x 6 columns]
